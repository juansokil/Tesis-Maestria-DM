# %%
import pandas as pd
import os 
import numpy as np


#df = pd.read_csv('/mnt/c/source/PUNTAJESZ.txt', sep='\t', encoding="latin1",  index_col=0 , dtype=np.float32)
df = pd.read_csv('/mnt/c/source/PUNTAJESZ.txt', sep='\t', encoding="latin1")

# %%
import pandas as pd
import os 
import numpy as np

# %%
datos = df.drop(['continente','iso'], axis=1)
# Select the ones you want
nombres = df[['continente','iso']]

# %%
datos=datos.astype(np.float64)

# %%
result = pd.concat([nombres, datos], axis=1, join='inner')
result=result.set_index(result.columns[1])
display(result)
# Out:
#     continente  T96   T21   T43   T52   T03  T08  T12  T84   T06  ...  T30  \
# iso                                                               ...
# BW      Africa  NaN   NaN   NaN  1.64  1.64  NaN  NaN  NaN   NaN  ...  NaN
# CM      Africa  NaN   NaN  1.64   NaN   NaN  NaN  NaN  NaN  1.64  ...  NaN
# EG      Africa  NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN  ...  NaN
# ET      Africa  NaN   NaN   NaN   NaN  1.64  NaN  NaN  NaN   NaN  ...  NaN
# GH      Africa  NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN  ...  NaN
# ..         ...  ...   ...   ...   ...   ...  ...  ...  ...   ...  ...  ...
# SI      Europa  NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN  ...  NaN
# SK      Europa  NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN  ...  NaN
# UA      Europa  NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN  ...  NaN
# AU     Oceania  NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN  ...  NaN
# NZ     Oceania  NaN  1.64   NaN   NaN   NaN  NaN  NaN  NaN   NaN  ...  NaN
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams["axes.labelsize"] = 20

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors

#cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ["red","orange","green"])


colors = {"green":3,"red":1}
l_colors = sorted(colors, key=colors.get)

# %%
#result=result.set_index(result.columns[1])
plt.figure(figsize=(18, 18))
plt.xticks(rotation=0)
plt.yticks(rotation=270)

sns.heatmap(result.loc[:, 'T96':'T38':1].transpose(), cmap=l_colors, vmin=1, vmax=len(colors), cbar=False, square=True, 
         linewidths=2, linecolor='black', cbar_kws={"orientation": "horizontal"})
# Out:
# <AxesSubplot:xlabel='iso'>

# %%
#result=result.set_index(result.columns[1])
plt.figure(figsize=(12, 12))
plt.xticks(rotation=0)
plt.yticks(rotation=270)



america=result.loc[result['continente'] == 'America']
sns.heatmap(america.loc[:, 'T96':'T38':1].transpose(), cmap=l_colors, vmin=1, vmax=len(colors), cbar=False, square=True, 
         linewidths=2, linecolor='black', cbar_kws={"orientation": "horizontal"})
# Out:
# <AxesSubplot:xlabel='iso'>

# %%
plt.figure(figsize=(16, 16))
plt.xticks(rotation=0)
plt.yticks(rotation=270)

europa=result.loc[result['continente'] == 'Europa']
sns.heatmap(europa.loc[:, 'T96':'T38':1].transpose(), cmap=l_colors, vmin=1, vmax=len(colors), cbar=False, square=True, 
         linewidths=2, linecolor='black', cbar_kws={"orientation": "horizontal"})
# Out:
# <AxesSubplot:xlabel='iso'>

# %%
plt.figure(figsize=(16, 16))
#plt.xticks(rotation=0)


asia=result.loc[result['continente'] == 'Asia']
#plt.xticks(rotation=90)
sns.heatmap(asia.loc[:, 'T96':'T38':1].transpose(), cmap=l_colors, vmin=1, vmax=len(colors), cbar=False, square=True, 
         linewidths=2, linecolor='black', cbar_kws={"orientation": "horizontal"})
# Out:
# <AxesSubplot:xlabel='iso'>

# %%
plt.figure(figsize=(16, 16))
plt.xticks(rotation=0)
plt.yticks(rotation=270)

africa=result.loc[result['continente'] == 'Africa']
sns.heatmap(africa.loc[:, 'T96':'T38':1].transpose(), cmap=l_colors, vmin=1, vmax=len(colors), cbar=False, square=True, 
         linewidths=2, linecolor='black', cbar_kws={"orientation": "horizontal"})
# Out:
# <AxesSubplot:xlabel='iso'>

# %%
###Con esto puedo detectar el encoding###
with open('C:\Users\Juan\Desktop\Materiales TESIS PARA APLICACION\PUNTAJES_Z.txt', 'rb') as f:
    result = chardet.detect(f.read())  # or readline if the file is large
    result
# Out:
#   File "<ipython-input-43-3b19ce6e05ab>", line 2
#     with open('C:\Users\Juan\Desktop\Materiales TESIS PARA APLICACION\PUNTAJES_Z.txt', 'rb') as f:
#              ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# ANALISIS REGIONAL

# %%
#df = pd.read_csv('/mnt/c/source/PUNTAJESZ.txt', sep='\t', encoding="latin1",  index_col=0 , dtype=np.float32)
df = pd.read_csv('/mnt/c/source/PUNTAJES_Z_ANEXO_REGIONAL.csv', sep=';', encoding="latin1")

# %%
df
# Out:
#               Region  T96  T21  T43  T52  T03  T08  T12  T84  T06  ...  T30  \
# 0    Africa Oriental  NaN  NaN  NaN  NaN  2.0  NaN  2.0  NaN  2.0  ...  2.0
# 1    America del Sur  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 2       Asia del Sur  NaN  NaN  NaN  NaN  NaN  2.0  NaN  NaN  NaN  ...  NaN
# 3    Asia Occidental  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 4   Europa del Norte  2.0  2.0  NaN  NaN  NaN  NaN  NaN  2.0  NaN  ...  NaN
# 5     Europa del Sur  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 6  Europa Occidental  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 7    Europa Oriental  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 8   Sudeste Asiatico  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
#
#    T33  T16  T48  T59  T94  T97  T99  T36  T38
# 0  2.0  2.0  2.0  NaN  NaN  NaN  NaN  NaN  2.0
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  2.0  NaN  NaN  NaN
# ...

# %%
datos = df.drop(['Region'], axis=1)
# Select the ones you want
nombres = df[['Region']]

# %%
datos=datos.astype(np.float64)

# %%
result = pd.concat([nombres, datos], axis=1, join='inner')
result=result.set_index(result.columns[0])
display(result)
# Out:
#                    T96  T21  T43  T52  T03  T08  T12  T84  T06  T41  ...  T30  \
# Region                                                               ...
# Africa Oriental    NaN  NaN  NaN  NaN  2.0  NaN  2.0  NaN  2.0  NaN  ...  2.0
# America del Sur    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# Asia del Sur       NaN  NaN  NaN  NaN  NaN  2.0  NaN  NaN  NaN  NaN  ...  NaN
# Asia Occidental    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# Europa del Norte   2.0  2.0  NaN  NaN  NaN  NaN  NaN  2.0  NaN  NaN  ...  NaN
# Europa del Sur     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# Europa Occidental  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# Europa Oriental    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN -2.0  ...  NaN
# Sudeste Asiatico   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
#
#                    T33  T16  T48  T59  T94  T97  T99  T36  T38
# Region
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams["axes.labelsize"] = 20

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors

#cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ["red","orange","green"])

# %%
colors = {"white":3,"green":2,"red":1}
l_colors = sorted(colors, key=colors.get)

#result=result.set_index(result.columns[1])
plt.figure(figsize=(16, 16))
plt.xticks(rotation=0)
#plt.yticks(rotation=270)

sns.heatmap(result.loc[:, 'T96':'T38':1].transpose(), cmap=l_colors, vmin=1, vmax=len(colors), cbar=False, square=False, 
         linewidths=2, linecolor='black', cbar_kws={"orientation": "horizontal"})
# Out:
# <AxesSubplot:xlabel='Region'>
